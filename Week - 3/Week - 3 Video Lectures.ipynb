# %% [markdown]
# ![Venn Diagram](merging1.png)

# %% [markdown]
# This is a venn diagram. The circle on the left is the population of students in a university. The circle on the right is the population of staff in the university. And the overlaping region in the middle is all those students who are staff, may be these students can be a part of research activity or some graded assignment.

# %%
#We will now see how we can use merge function or how we can merge the dataframes in order to get required information

import pandas as pd
import numpy as np

#We will now create two dataframes one staff and other students

staff_df = pd.DataFrame([{"Name":'Amit','Role':'Marketing HOD'},
                         {'Name':'Priya','Role':'Controller of Examination'},
                        {'Name':'Mohit','Role':'Researcher'}])

staff_df = staff_df.set_index('Name')


student_df = pd.DataFrame([{'Name':'Manoj','School':'Business'},
                          {'Name':'Priya','School':'Law'},
                          {'Name':'Mohit','School':'Engineering'}])


student_df = student_df.set_index('Name')

print(staff_df)
print(student_df)
# Out:
#                             Role
# Name
# Amit               Marketing HOD
# Priya  Controller of Examination
# Mohit                 Researcher
#             School
# Name
# Manoj     Business
# Priya          Law
# Mohit  Engineering

# %%
#In these two dataframe Mohit and Priya are in both student and staff.
#If we want to get an outer join after combining both the dfs, we will use merge function and use join type as outer and we will
#use left and right indices as joining column

#left_index = True and Right_index = True states that we need to consider indexes of both dfs while joinin
pd.merge(staff_df,student_df,left_index=True,right_index=True, how='outer')
# Out:
#                             Role       School
# Name
# Amit               Marketing HOD          NaN
# Manoj                        NaN     Business
# Mohit                 Researcher  Engineering
# Priya  Controller of Examination          Law

# %%
#Now if we want to get intersection of these two df we will use inner join
pd.merge(staff_df,student_df,left_index=True,right_index=True, how='inner')

#By merge uses inner join
# Out:
#                             Role       School
# Name
# Priya  Controller of Examination          Law
# Mohit                 Researcher  Engineering

# %%
#Now we want to get a list of all staff regardless of whether they're students or not. But if there were students, we'd 
#want to get their student details as well. To do this, we would use a left join. It's important to note that the order 
#of DataFrames in this function, the first DataFrame is the left DataFrame and the second is the right.

pd.merge(staff_df,student_df,how='left',left_index=True,right_index=True)
# Out:
#                             Role       School
# Name
# Amit               Marketing HOD          NaN
# Priya  Controller of Examination          Law
# Mohit                 Researcher  Engineering

# %%
#We want a list of all of the students and their roles if they are also staff. To do this, we would do a right join.

pd.merge(staff_df,student_df,how='right',left_index=True,right_index=True)
# Out:
#                             Role       School
# Name
# Manoj                        NaN     Business
# Priya  Controller of Examination          Law
# Mohit                 Researcher  Engineering

# %%
#Now we will use 'on' parameter of merge instead of left_index and right_index

staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

pd.merge(staff_df,student_df,how='inner',on='Name')
# Out:
#     Name                       Role       School
# 0  Priya  Controller of Examination          Law
# 1  Mohit                 Researcher  Engineering

# %%
#We will now see merge in some more depth

staff_df = pd.DataFrame([{"Name":'Amit','Role':'Marketing HOD','Location':'Office 22'},
                         {'Name':'Priya','Role':'Controller of Examination','Location':'Office 26'},
                        {'Name':'Mohit','Role':'Researcher','Location':'Office 35'}])




student_df = pd.DataFrame([{'Name':'Manoj','School':'Business','Location':'Indra Nagar'},
                          {'Name':'Priya','School':'Law','Location':'RT Nagar'},
                          {'Name':'Mohit','School':'Engineering','Location':'Ejipura'}])

# %%
#The staff DataFrame, this is an office location where we can find the staff person, but for the student DataFrame, the 
#location information is actually their home address. The merge function preserves this information, but depends either 
#on underscore x or underscore y to help differentiate which index went with which column of data. The underscore x is 
#always the left DataFrame information and the underscore y is always the right DataFrame information.

#Here if we want to get details of staff members and check whether if they are students then difference in theior location

pd.merge(staff_df,student_df,how='left',on='Name')
# Out:
#     Name                       Role Location_x       School Location_y
# 0   Amit              Marketing HOD  Office 22          NaN        NaN
# 1  Priya  Controller of Examination  Office 26          Law   RT Nagar
# 2  Mohit                 Researcher  Office 35  Engineering    Ejipura

# %%
#We can change the suffix of the loaction if we want  

pd.merge(staff_df,student_df,suffixes=('_office','_home'), how='left',on='Name')
# Out:
#     Name                       Role Location_office       School Location_home
# 0   Amit              Marketing HOD       Office 22          NaN           NaN
# 1  Priya  Controller of Examination       Office 26          Law      RT Nagar
# 2  Mohit                 Researcher       Office 35  Engineering       Ejipura

# %%
#We will now talk about multi indexing and multiplt columns. 

#It is quite possible that there are chances that the there can be more than one column whose value overlap in the two dFs
#in that case we pass the list of those two columns names to the "on" parameter. 

staff_df = pd.DataFrame([{"first_name":'Amit','last_name':'Kapoor','Role':'Marketing HOD'},
                         {'first_name':'Priya','last_name':'Gupta','Role':'Controller of Examination'},
                        {'first_name':'Mohit','last_name':'Aggarwal','Role':'Researcher'}])



student_df = pd.DataFrame([{'first_name':'Manoj','last_name':'Kapoor','School':'Business'},
                          {'first_name':'Priya','last_name':'Gupta','School':'Law'},
                          {'first_name':'Mohit','last_name':'Aggarwal','School':'Engineering'}])

print(staff_df)
print(student_df)
# Out:
#   first_name last_name                       Role
# 0       Amit    Kapoor              Marketing HOD
# 1      Priya     Gupta  Controller of Examination
# 2      Mohit  Aggarwal                 Researcher
#   first_name last_name       School
# 0      Manoj    Kapoor     Business
# 1      Priya     Gupta          Law
# 2      Mohit  Aggarwal  Engineering

# %%
#We will now perform inner join on the dataframes 

pd.merge(staff_df,student_df,on=['first_name','last_name'], how='inner')
# Out:
#   first_name last_name                       Role       School
# 0      Priya     Gupta  Controller of Examination          Law
# 1      Mohit  Aggarwal                 Researcher  Engineering

# %%
#If we think of merging as joining ''horizontally,'' meaning we join on similar values in a column found in two dataframes, 
#then concatenating is joining ''vertically,'' meaning we put dataframes on top or at the bottom of one another

#We will see some of the examples now 

#Let's take a look at the US Department of Education College Scorecard data. It has each US university's data on student 
#completion, student debt, after graduation income, and others. The data is stored in separate CSVs, with each CSV containing 
#a year's record. Let's say we wanted the records from 2011-2013. We create first three dataframes, each containing one year's 
#record, and because the CSV files we're working with are messy, I want to suppress some of the Jupyter warning messages 
#and just tell read_csv to ignore bad lines. So I'm going to start the cell with the cell magic, %%capture. 
#It's just to suppress output as we're loading these CSV files because there are errors in them. 



df1 = pd.read_csv('datasets/college_scorecard/MERGED2011_12_PP.csv',error_bad_lines=False)
df2 = pd.read_csv('datasets/college_scorecard/MERGED2012_13_PP.csv',error_bad_lines=False)
df3 = pd.read_csv('datasets/college_scorecard/MERGED2013_14_PP.csv',error_bad_lines=False)
# Out:
# b'Skipping line 309: expected 1977 fields, saw 2485\nSkipping line 514: expected 1977 fields, saw 2552\n'
# b'Skipping line 615: expected 1977 fields, saw 2425\nSkipping line 922: expected 1977 fields, saw 2270\nSkipping line 1026: expected 1977 fields, saw 2199\n'
# b'Skipping line 1129: expected 1977 fields, saw 2212\nSkipping line 1439: expected 1977 fields, saw 2476\nSkipping line 1543: expected 1977 fields, saw 2103\n'
# b'Skipping line 1852: expected 1977 fields, saw 3023\n'
# b'Skipping line 2161: expected 1977 fields, saw 2372\nSkipping line 2473: expected 1977 fields, saw 2559\n'
# b'Skipping line 2576: expected 1977 fields, saw 2328\nSkipping line 2880: expected 1977 fields, saw 3153\nSkipping line 2981: expected 1977 fields, saw 2103\n'
# b'Skipping line 3388: expected 1977 fields, saw 2074\nSkipping line 3489: expected 1977 fields, saw 3116\n'
# b'Skipping line 3694: expected 1977 fields, saw 2135\nSkipping line 4006: expected 1977 fields, saw 2585\n'
# b'Skipping line 4212: expected 1977 fields, saw 2018\nSkipping line 4312: expected 1977 fields, saw 2957\nSkipping line 4620: expected 1977 fields, saw 3152\n'
# b'Skipping line 4824: expected 1977 fields, saw 3607\n'
# b'Skipping line 5232: expected 1977 fields, saw 2135\nSkipping line 5435: expected 1977 fields, saw 2475\n'
# b'Skipping line 5738: expected 1977 fields, saw 2177\nSkipping line 5838: expected 1977 fields, saw 2037\nSkipping line 6147: expected 1977 fields, saw 2381\n'
# b'Skipping line 6352: expected 1977 fields, saw 3093\nSkipping line 6555: expected 1977 fields, saw 2635\n'
# b'Skipping line 6757: expected 1977 fields, saw 2209\nSkipping line 7068: expected 1977 fields, saw 2618\n'
# b'Skipping line 7577: expected 1977 fields, saw 2621\n'
# b'Skipping line 7994: expected 1977 fields, saw 2133\nSkipping line 8095: expected 1977 fields, saw 2135\nSkipping line 8196: expected 1977 fields, saw 2756\n'
# b'Skipping line 8501: expected 1977 fields, saw 2196\nSkipping line 8605: expected 1977 fields, saw 3014\n'
# b'Skipping line 8817: expected 1977 fields, saw 2322\nSkipping line 8920: expected 1977 fields, saw 2332\nSkipping line 9121: expected 1977 fields, saw 2309\nSkipping line 9219: expected 1977 fields, saw 2423\n'
# b'Skipping line 9516: expected 1977 fields, saw 2133\n'
# b'Skipping line 9812: expected 1977 fields, saw 2254\nSkipping line 10013: expected 1977 fields, saw 2720\nSkipping line 10212: expected 1977 fields, saw 2202\n'
# b'Skipping line 10404: expected 1977 fields, saw 2346\nSkipping line 10599: expected 1977 fields, saw 2466\n'
# b'Skipping line 10898: expected 1998 fields, saw 2398\nSkipping line 10999: expected 1998 fields, saw 2548\n'
# b'Skipping line 11409: expected 1998 fields, saw 2683\nSkipping line 11509: expected 1998 fields, saw 2606\nSkipping line 11819: expected 1998 fields, saw 2353\n'
# b'Skipping line 12022: expected 1998 fields, saw 2103\nSkipping line 12225: expected 1998 fields, saw 2397\nSkipping line 12328: expected 1998 fields, saw 2400\n'
# b'Skipping line 12642: expected 1998 fields, saw 2723\n'
# b'Skipping line 12861: expected 1998 fields, saw 2097\nSkipping line 12973: expected 1998 fields, saw 2243\n'
# b'Skipping line 13431: expected 1998 fields, saw 2601\n'
# b'Skipping line 13904: expected 1998 fields, saw 2332\nSkipping line 14020: expected 1998 fields, saw 2865\n'
# b'Skipping line 14407: expected 1998 fields, saw 3264\nSkipping line 14628: expected 1998 fields, saw 2018\n'
# b'Skipping line 14939: expected 1998 fields, saw 2146\nSkipping line 15043: expected 1998 fields, saw 2848\n'

# %%
df1.head(2)
# Out:
#      UNITID     OPEID OPEID6                               INSTNM        CITY  \
# 0  100654.0  100200.0   1002             Alabama A & M University      Normal
# 1  100663.0  105200.0   1052  University of Alabama at Birmingham  Birmingham
#
#   STABBR         ZIP  ACCREDAGENCY INSTURL NPCURL  ...  \
# 0     AL       35762           NaN     NaN    NaN  ...
# 1     AL  35294-0110           NaN     NaN    NaN  ...
#
#   OMAWDP8_NOTFIRSTTIME_POOLED_SUPP OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
#
#   OMENRYP_FULLTIME_POOLED_SUPP OMENRAP_FULLTIME_POOLED_SUPP  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#   OMAWDP8_FULLTIME_POOLED_SUPP OMENRUP_FULLTIME_POOLED_SUPP  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#   OMENRYP_PARTTIME_POOLED_SUPP OMENRAP_PARTTIME_POOLED_SUPP  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#   OMAWDP8_PARTTIME_POOLED_SUPP OMENRUP_PARTTIME_POOLED_SUPP
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
# [2 rows x 1977 columns]

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (15235, 1977)
# (7793, 1977)
# (7804, 1977)

# %%
print(len(df1))
print(len(df2))
print(len(df3))
# Out:
# 15235
# 7793
# 7804

# %%
#We will now pass these dataframes and concatinate these into on dataframe
df_list = [df1,df2,df3]

merged_df =pd.concat(df_list)
len(merged_df)
# Out:
# 30832

# %%
#we will verify whether all the dfs merged successfully or not
len(df1)+len(df2)+len(df3)
# Out:
# 30832

# %%
#But there is a problem now we dont know which record belongs to which year. pd.concat has a solution to this problem,
#We will pass key parameter

merged_df = pd.concat(df_list,keys=['2011','2012','2013'])

# %%
#If you're concatenating two dataframes that do not have identical columns, and choose the outer methods, some cells will 
#be NaN. If you choose to do the inner, then some observations will be dropped due to NaN values. You can think this as 
#analogous to the left and right joints of the merge function.

# %% [markdown]
# ## Grouping
#
# The idea behind groupby is that it takes some data frame, splits it into chunks based on some key values, and then applies computation on those chunks, and then combines the result back together into another data frame. In pandas it is referred to as split-apply-combine pattern.

# %%
import pandas as pd
import numpy as np

# %%
#we will read some US census data 

df = pd.read_csv('datasets/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %%
#We will only those values which have sum level of 50

df = df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
# 5         -1.177622         -1.748766         -2.062535         -1.369970
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
# 5     1.859511    -0.848580    -1.402476    -1.577232    -0.884411
#
# [5 rows x 100 columns]

# %%
#Let us see the average of census population of 2010
for group,frame in df.groupby('STNAME'):
    average= np.average(frame['CENSUS2010POP'])
    print("Population of state "+ group + 
         "is " + str(average))
# Out:
# Population of state Alabamais 71339.34328358209
# Population of state Alaskais 24490.724137931036
# Population of state Arizonais 426134.4666666667
# Population of state Arkansasis 38878.90666666667
# Population of state Californiais 642309.5862068966
# Population of state Coloradois 78581.1875
# Population of state Connecticutis 446762.125
# Population of state Delawareis 299311.3333333333
# Population of state District of Columbiais 601723.0
# Population of state Floridais 280616.5671641791
# Population of state Georgiais 60928.63522012578
# Population of state Hawaiiis 272060.2
# Population of state Idahois 35626.86363636364
# Population of state Illinoisis 125790.50980392157
# Population of state Indianais 70476.10869565218
# Population of state Iowais 30771.262626262625
# Population of state Kansasis 27172.55238095238
# Population of state Kentuckyis 36161.39166666667
# Population of state Louisianais 70833.9375
# Population of state Maineis 83022.5625
# Population of state Marylandis 240564.66666666666
# Population of state Massachusettsis 467687.78571428574
# Population of state Michiganis 119080.0
# Population of state Minnesotais 60964.65517241379
# Population of state Mississippiis 36186.54878048781
# Population of state Missouriis 52077.62608695652
# Population of state Montanais 17668.125
# Population of state Nebraskais 19638.075268817203
# Population of state Nevadais 158855.9411764706
# Population of state New Hampshireis 131647.0
# Population of state New Jerseyis 418661.61904761905
# Population of state New Mexicois 62399.36363636364
# Population of state New Yorkis 312550.03225806454
# Population of state North Carolinais 95354.83
# Population of state North Dakotais 12690.396226415094
# Population of state Ohiois 131096.63636363635
# Population of state Oklahomais 48718.844155844155
# Population of state Oregonis 106418.72222222222
# Population of state Pennsylvaniais 189587.74626865672
# Population of state Rhode Islandis 210513.4
# Population of state South Carolinais 100551.39130434782
# Population of state South Dakotais 12336.060606060606
# Population of state Tennesseeis 66801.1052631579
# Population of state Texasis 98998.27165354331
# Population of state Utahis 95306.37931034483
# Population of state Vermontis 44695.78571428572
# Population of state Virginiais 60111.29323308271
# Population of state Washingtonis 172424.10256410256
# Population of state West Virginiais 33690.8
# Population of state Wisconsinis 78985.91666666667
# Population of state Wyomingis 24505.478260869564

# %%
#We'll create some new function called set_batch_number. If the first number of the parameter is the capital M, we'll 
#return a zero. If it's capital Q, we'll return a one. Otherwise, we'll return a two. Then we'll pass this function to 
#the DataFrame. 
df = df.set_index('STNAME')
def set_batch(item):
    if item[0]<'M':
        return 0
    if item[0] <'Q':
        return 1
    else:
        return 2

# %%
for group,frame in df.groupby(set_batch):
    print("There are " + str(len(frame)) +  ' records in group ' + str(group))
# Out:
# There are 1177 records in group 0
# There are 1134 records in group 1
# There are 831 records in group 2

# %%
#Notice i did not pass any column name to groupby(). Instead I set the index of the dataframe to SETNAME and when no identifier
#is passed to groupby it will automatically use the index as the identifier for groupby

# %%
#Let us read another dataset 
df = pd.read_csv('datasets/listings.csv')
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
#In the above df we want to groupby on the basis of 2 columns one is cancellation policy and other is review scores value
#There are 2 ways to do that
#First we will set these two columns as multilevel index and we wont neet to pass columns to groupby

df.set_index(['cancellation_policy','review_scores_value'],inplace=True)

for group,level in df.groupby(level=(0,1)):
    print(group)
# Out:
# ('flexible', 2.0)
# ('flexible', 4.0)
# ('flexible', 5.0)
# ('flexible', 6.0)
# ('flexible', 7.0)
# ('flexible', 8.0)
# ('flexible', 9.0)
# ('flexible', 10.0)
# ('moderate', 2.0)
# ('moderate', 4.0)
# ('moderate', 6.0)
# ('moderate', 7.0)
# ('moderate', 8.0)
# ('moderate', 9.0)
# ('moderate', 10.0)
# ('strict', 2.0)
# ('strict', 3.0)
# ('strict', 4.0)
# ('strict', 5.0)
# ('strict', 6.0)
# ('strict', 7.0)
# ('strict', 8.0)
# ('strict', 9.0)
# ('strict', 10.0)
# ('super_strict_30', 6.0)
# ('super_strict_30', 7.0)
# ('super_strict_30', 8.0)
# ('super_strict_30', 9.0)
# ('super_strict_30', 10.0)

# %%
def grouping_func(item):
    if item[1]==10.0:
        return (item[0],"10.0")
    else:
        return (item[0],"Not 10.00")
    
for group,frame in df.groupby(by=grouping_func):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'Not 10.00')
# ('moderate', '10.0')
# ('moderate', 'Not 10.00')
# ('strict', '10.0')
# ('strict', 'Not 10.00')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'Not 10.00')

# %%
#There is another method to do the same thing 
df = pd.read_csv('datasets/listings.csv')

# %%
df['review_scores_value']= np.where(df['review_scores_value']==10.00,'10.00','Not 10.00')
for group, label in df.groupby(by=['cancellation_policy','review_scores_value']):
    print(group)
# Out:
# ('flexible', '10.00')
# ('flexible', 'Not 10.00')
# ('moderate', '10.00')
# ('moderate', 'Not 10.00')
# ('strict', '10.00')
# ('strict', 'Not 10.00')
# ('super_strict_30', '10.00')
# ('super_strict_30', 'Not 10.00')

# %%
#The panda's developers have three broad categories of data processing to happen during the apply step. Aggregations 
#of group data, transformation of group data, and filtration of group data

# %% [markdown]
# ### Aggregation

# %%
#The apply step in split-apply-combine is the aggregation of data
#let us use our last dataset

#letus reload that again

df = pd.read_csv('datasets/listings.csv')
df.groupby('cancellation_policy').agg({'review_scores_value':np.nanmean})

#Instead of not using agg we can use the below code also to get same result
#df.groupby('cancellation_policy',as_index=False)['review_scores_value'].mean()
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                        9.237421
# moderate                        9.307398
# strict                          9.081441
# super_strict_30                 8.537313

# %%
#We can pass multiple number ofcolumns and multiple functions to the column we wan to aggregate 
df.groupby('cancellation_policy').agg({'review_scores_value':(np.nanmean,np.nanstd,np.nanmedian),
                                      'reviews_per_month':(np.nanmean,np.nanstd,np.nanmedian)})
# Out:
#                     review_scores_value                     reviews_per_month  \
#                                 nanmean    nanstd nanmedian           nanmean
# cancellation_policy
# flexible                       9.237421  1.096271      10.0          1.829210
# moderate                       9.307398  0.859859       9.0          2.391922
# strict                         9.081441  1.040531       9.0          1.873467
# super_strict_30                8.537313  0.840785       9.0          0.340143
#
#
#                        nanstd nanmedian
# cancellation_policy
# flexible             2.005405     1.000
# moderate             2.432009     1.615
# strict               1.953800     1.210
# super_strict_30      0.752392     0.140

# %% [markdown]
# ### Transaformation

# %%
#Transformation is different from aggregation. agg() returns a single value per category/group, transform returns an objec 
#that is the same size as the group. Essentially it broadcasts the function you supply over the grouped df, returning a new df.

transformed_df = df.groupby('cancellation_policy',as_index=False)['review_scores_value'].transform(np.nanmean)
transformed_df.rename(columns={'review_scores_value':'mean_review_scores_value'},inplace=True)
transformed_df.head()
# Out:
#    mean_review_scores_value
# 0                  9.307398
# 1                  9.307398
# 2                  9.307398
# 3                  9.307398
# 4                  9.237421

# %%
#We will now concatinate this to the main df or we can perform merge
df = pd.concat([df,transformed_df],axis=1)

#df.merge(transform_df,left_index=True,right_index=True)

# %%
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... requires_license  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                f
# 1  The room is in Roslindale, a diverse and prima...  ...                f
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                f
# 3  Roslindale is a lovely little neighborhood loc...  ...                f
# 4  I love the proximity to downtown, the neighbor...  ...                f
#
#   license jurisdiction_names instant_bookable cancellation_policy  \
# 0     NaN                NaN                f            moderate
# 1     NaN                NaN                t            moderate
# 2     NaN                NaN                f            moderate
# 3     NaN                NaN                f            moderate
# 4     NaN                NaN                f            flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             t                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count reviews_per_month  mean_review_scores_value
# 0                              1               NaN                  9.307398
# 1                              1              1.30                  9.307398
# 2                              1              0.47                  9.307398
# 3                              1              1.00                  9.307398
# 4                              1              2.25                  9.237421
#
# [5 rows x 96 columns]

# %%
#Now we will calculate the difference between the actual and mean value of review_score_value
df['difference'] = abs(df['review_scores_value']-df['mean_review_scores_value'])
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... license  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...     NaN
# 1  The room is in Roslindale, a diverse and prima...  ...     NaN
# 2  The LOCATION: Roslindale is a safe and diverse...  ...     NaN
# 3  Roslindale is a lovely little neighborhood loc...  ...     NaN
# 4  I love the proximity to downtown, the neighbor...  ...     NaN
#
#   jurisdiction_names instant_bookable cancellation_policy  \
# 0                NaN                f            moderate
# 1                NaN                t            moderate
# 2                NaN                f            moderate
# 3                NaN                f            moderate
# 4                NaN                f            flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             t                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count reviews_per_month mean_review_scores_value  \
# 0                              1               NaN                 9.307398
# 1                              1              1.30                 9.307398
# 2                              1              0.47                 9.307398
# 3                              1              1.00                 9.307398
# 4                              1              2.25                 9.237421
#
#    difference
# 0         NaN
# 1    0.307398
# 2    0.692602
# 3    0.692602
# 4    0.762579
#
# [5 rows x 97 columns]

# %% [markdown]
# ### Filter

# %%
#Group-by object is built-in support for filtering groups as well. It's often that you'll want to group by some features 
#then make some transformations to the groups, then drop certain groups as part of your cleaning routine. 
#The Filter Function takes in a function which it applies to each group data frame and returns either a true or false, 
#depending on whether that group should be included in the results.

df.groupby('cancellation_policy').filter(lambda x: np.mean(x['review_scores_value'])>9.2)
# Out:
#             id                            listing_url       scrape_id  \
# 0     12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1      3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2         6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3      1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4      7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# ...        ...                                    ...             ...
# 3576  14689681  https://www.airbnb.com/rooms/14689681  20160906204935
# 3577  13750763  https://www.airbnb.com/rooms/13750763  20160906204935
# 3579  14852179  https://www.airbnb.com/rooms/14852179  20160906204935
# 3582  14585486  https://www.airbnb.com/rooms/14585486  20160906204935
# 3584  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
#
#      last_scraped                                               name  \
# 0      2016-09-07                         Sunny Bungalow in the City
# 1      2016-09-07                  Charming room in pet friendly apt
# 2      2016-09-07                   Mexican Folk Art Haven in Boston
# 3      2016-09-07      Spacious Sunny Bedroom Suite in Historic Home
# 4      2016-09-07                                Come Home to Boston
# ...           ...                                                ...
# 3576   2016-09-07   Beautiful loft style bedroom with large bathroom
# 3577   2016-09-07        Comfortable Space in the Heart of Brookline
# 3579   2016-09-07  Spacious Queen Bed Room Close to Boston Univer...
# 3582   2016-09-07                           Gorgeous funky apartment
# 3584   2016-09-07                 (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# ...                                                 ...
# 3576  You'd be living on the top floor of a four sto...
# 3577  Our place is close to Coolidge Corner, Allston...
# 3579  - Grocery: A full-size Star market is 2 minute...
# 3582  Funky little apartment close to public transpo...
# 3584  My place is close to My home is a warm and fri...
#
#                                                   space  \
# 0     The house has an open and cozy feel at the sam...
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# ...                                                 ...
# 3576                                                NaN
# 3577  This space consists of 2 Rooms and a private b...
# 3579                                                NaN
# 3582  Modern and relaxed space with many facilities ...
# 3584  To ensure a smooth check in: 1. You MUST have ...
#
#                                             description experiences_offered  \
# 0     Cozy, sunny, family home.  Master bedroom high...                none
# 1     Charming and quiet room in a second floor 1910...                none
# 2     Come stay with a friendly, middle-aged guy in ...                none
# 3     Come experience the comforts of home away from...                none
# 4     My comfy, clean and relaxing home is one block...                none
# ...                                                 ...                 ...
# 3576  You'd be living on the top floor of a four sto...                none
# 3577  Our place is close to Coolidge Corner, Allston...                none
# 3579  - Grocery: A full-size Star market is 2 minute...                none
# 3582  Funky little apartment close to public transpo...                none
# 3584  My place is close to My home is a warm and fri...                none
#
#                                   neighborhood_overview  ... license  \
# 0     Roslindale is quiet, convenient and friendly. ...  ...     NaN
# 1     The room is in Roslindale, a diverse and prima...  ...     NaN
# 2     The LOCATION: Roslindale is a safe and diverse...  ...     NaN
# 3     Roslindale is a lovely little neighborhood loc...  ...     NaN
# 4     I love the proximity to downtown, the neighbor...  ...     NaN
# ...                                                 ...  ...     ...
# 3576                                                NaN  ...     NaN
# 3577  Brookline is known for being an excellent and ...  ...     NaN
# 3579                                                NaN  ...     NaN
# 3582  Cambridge is a short walk into Boston, and set...  ...     NaN
# 3584                                                NaN  ...     NaN
#
#      jurisdiction_names instant_bookable cancellation_policy  \
# 0                   NaN                f            moderate
# 1                   NaN                t            moderate
# 2                   NaN                f            moderate
# 3                   NaN                f            moderate
# 4                   NaN                f            flexible
# ...                 ...              ...                 ...
# 3576                NaN                f            flexible
# 3577                NaN                f            flexible
# 3579                NaN                f            flexible
# 3582                NaN                f            flexible
# 3584                NaN                t            flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                f
# 2                                t                                f
# 3                                f                                f
# 4                                f                                f
# ...                            ...                              ...
# 3576                             f                                f
# 3577                             f                                f
# 3579                             f                                f
# 3582                             f                                f
# 3584                             f                                f
#
#      calculated_host_listings_count reviews_per_month  \
# 0                                 1               NaN
# 1                                 1              1.30
# 2                                 1              0.47
# 3                                 1              1.00
# 4                                 1              2.25
# ...                             ...               ...
# 3576                              1               NaN
# 3577                              1               NaN
# 3579                              1               NaN
# 3582                              1               NaN
# 3584                              3               NaN
#
#      mean_review_scores_value  difference
# 0                    9.307398         NaN
# 1                    9.307398    0.307398
# 2                    9.307398    0.692602
# 3                    9.307398    0.692602
# 4                    9.237421    0.762579
# ...                       ...         ...
# 3576                 9.237421         NaN
# 3577                 9.237421         NaN
# 3579                 9.237421         NaN
# 3582                 9.237421         NaN
# 3584                 9.237421         NaN
#
# [1918 rows x 97 columns]

# %% [markdown]
# ### Apply

# %%
# the most common operation I invoke on Group-by objects is the Apply function. This allows you to apply an arbitrary 
#function to each group and stitched the results back together for each apply into a single data frame where the index 
#is preserved.

#lets get the clean copy of the dataframe
df = pd.read_csv('datasets/listings.csv')
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
#We will just use two columns
df = df[['cancellation_policy','review_scores_value']]
df.head()
# Out:
#   cancellation_policy  review_scores_value
# 0            moderate                  NaN
# 1            moderate                  9.0
# 2            moderate                 10.0
# 3            moderate                 10.0
# 4            flexible                 10.0

# %%
#Now whatever we did in the last process we are going to do that again but with apply funciton 
def cal_review_scores(group):
    # group is a data frame just of whatever we've grouped, in this case the cancellation policy. So we can treat this 
    #as the complete data frame that we're operating on
    average = np.nanmean(group['review_scores_value'])
    group['mean_average_review_score'] = abs(average-group['review_scores_value'])
    return group

df.groupby('cancellation_policy').apply(cal_review_scores).head()
# Out:
#   cancellation_policy  review_scores_value  mean_average_review_score
# 0            moderate                  NaN                        NaN
# 1            moderate                  9.0                   0.307398
# 2            moderate                 10.0                   0.692602
# 3            moderate                 10.0                   0.692602
# 4            flexible                 10.0                   0.762579

# %% [markdown]
# ## Pivot Table

# %% [markdown]
# A pivot table is a way of summarizing data in a DataFrame for a particular purpose. It makes heavy use of this aggregation function we've been talking about. A pivot table is in itself a DataFrame, where the rows represent one variable that you're interested in, the columns another, and then the cells some aggregate value. A pivot table also tends to include marginal values as well, which are sum for each column and row. This allows you to be able to see the relationship between two variables at just a glance.

# %%
#Importing dataset
df = pd.read_csv('datasets/cwurData.csv')
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
# Let's say we wanted to create a new column called Rank_Level, where institutions with world rankings 1-100 are 
#categorized as first tier, and those with world rankings 101 to 200 are second tier, and ranking 201 to 300 are 
#third tier. Then after 301, we'll just bucket those as other top universities.

def university_label(group):
    
    if group <= 100:
        return '1st Tier'
    elif (group >100) & (group<=200):
        return '2nd Tier'
    elif (group >200) & (group<=300):
        return '3rd Tier'
    else:
        return 'Other'
    
df['Label'] = df['world_rank'].apply(lambda x: university_label(x))
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year  \
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012
#
#       Label
# 0  1st Tier
# 1  1st Tier
# 2  1st Tier
# 3  1st Tier
# 4  1st Tier

# %%
#Let us create our first pivot table

df.pivot_table(values='score',index='country',columns='Label',aggfunc=[np.sum])
# Out:
#                            sum
# Label                 1st Tier 2nd Tier 3rd Tier     Other
# country
# Argentina                  NaN      NaN      NaN    312.71
# Australia               383.54   393.94    94.57   1785.83
# Austria                    NaN      NaN   141.20    942.15
# Belgium                 103.75   245.42   140.24    450.81
# Brazil                     NaN    99.13      NaN   1512.99
# Bulgaria                   NaN      NaN      NaN     88.67
# Canada                  697.24   541.40   515.09   1656.14
# Chile                      NaN      NaN      NaN    358.14
# China                   214.37   239.34   375.41   6684.64
# Colombia                   NaN      NaN      NaN    177.73
# Croatia                    NaN      NaN      NaN     89.54
# Cyprus                     NaN      NaN      NaN     88.42
# Czech Republic             NaN      NaN    46.32    401.29
# Denmark                 196.72   195.86      NaN    180.71
# Egypt                      NaN      NaN      NaN    353.84
# Estonia                    NaN      NaN      NaN     89.62
# Finland                  88.83   100.80      NaN    721.00
# France                  934.46   342.22   565.51   3211.85
# Germany                 540.69   876.52  1266.58   2653.72
# Greece                     NaN      NaN      NaN    627.96
# Hong Kong                  NaN    97.25   141.30    316.99
# Hungary                    NaN      NaN      NaN    535.24
# Iceland                    NaN      NaN      NaN     89.96
# India                      NaN      NaN      NaN   1386.11
# Iran                       NaN      NaN      NaN    708.32
# Ireland                    NaN    95.69    93.56    534.51
# Israel                  788.30   100.01      NaN    270.08
# Italy                   146.21   243.09   421.75   3552.17
# Japan                  1529.13   344.10   279.28   5356.99
# Lebanon                    NaN      NaN      NaN     89.31
# Lithuania                  NaN      NaN      NaN     88.71
# Malaysia                   NaN      NaN      NaN    270.05
# Mexico                     NaN      NaN      NaN    180.41
# Netherlands             290.27   549.60   279.94    270.98
# New Zealand                NaN      NaN    93.03    448.32
# Norway                  141.17    50.70   139.34    224.75
# Poland                     NaN      NaN      NaN    800.95
# Portugal                   NaN      NaN   139.44    491.89
# Puerto Rico                NaN      NaN      NaN     88.35
# Romania                    NaN      NaN      NaN    132.40
# Russia                  155.54      NaN    93.04    177.85
# Saudi Arabia               NaN      NaN      NaN    356.09
# Serbia                     NaN      NaN      NaN     88.84
# Singapore               152.16    98.64      NaN       NaN
# Slovak Republic            NaN      NaN      NaN     88.98
# Slovenia                   NaN      NaN      NaN    178.46
# South Africa               NaN    99.15    93.36    271.48
# South Korea             279.95   442.23    94.98   2509.12
# Spain                      NaN   147.93   186.70   3309.63
# Sweden                  253.36   394.45   139.37    362.18
# Switzerland             864.08   240.92    47.93    178.50
# Taiwan                  108.42      NaN    94.13   1868.02
# Thailand                   NaN      NaN    46.55    224.15
# Turkey                     NaN      NaN      NaN    889.62
# USA                   13617.88  3091.38  2809.10  10185.88
# Uganda                     NaN      NaN      NaN     88.56
# United Arab Emirates       NaN      NaN      NaN     88.44
# United Kingdom         1854.20   783.32  1030.97   3455.86
# Uruguay                    NaN      NaN      NaN     88.51

# %%
#Here we can see there is hierarichal dataframe, for index we have conuntires and for the columns we have hieririchal result
#for the first level we have sum stating that the value used is sum and second level teels we are using labels

# %%
#We can pass multiple aggregated functions to the pivot table. let us try to do that too

#In this 
df.pivot_table(values='score',index='country',columns='Label',aggfunc=[np.sum,np.max,np.min])
# Out:
#                            sum                                 amax           \
# Label                 1st Tier 2nd Tier 3rd Tier     Other 1st Tier 2nd Tier
# country
# Argentina                  NaN      NaN      NaN    312.71      NaN      NaN
# Australia               383.54   393.94    94.57   1785.83    51.61    50.40
# Austria                    NaN      NaN   141.20    942.15      NaN      NaN
# Belgium                 103.75   245.42   140.24    450.81    52.03    49.73
# Brazil                     NaN    99.13      NaN   1512.99      NaN    49.82
# Bulgaria                   NaN      NaN      NaN     88.67      NaN      NaN
# Canada                  697.24   541.40   515.09   1656.14    60.87    51.23
# Chile                      NaN      NaN      NaN    358.14      NaN      NaN
# China                   214.37   239.34   375.41   6684.64    55.30    48.14
# Colombia                   NaN      NaN      NaN    177.73      NaN      NaN
# Croatia                    NaN      NaN      NaN     89.54      NaN      NaN
# Cyprus                     NaN      NaN      NaN     88.42      NaN      NaN
# Czech Republic             NaN      NaN    46.32    401.29      NaN      NaN
# Denmark                 196.72   195.86      NaN    180.71    52.94    50.17
# Egypt                      NaN      NaN      NaN    353.84      NaN      NaN
# Estonia                    NaN      NaN      NaN     89.62      NaN      NaN
# Finland                  88.83   100.80      NaN    721.00    44.44    50.76
# France                  934.46   342.22   565.51   3211.85    59.72    50.34
# Germany                 540.69   876.52  1266.58   2653.72    52.75    50.58
# Greece                     NaN      NaN      NaN    627.96      NaN      NaN
# Hong Kong                  NaN    97.25   141.30    316.99      NaN    49.10
# Hungary                    NaN      NaN      NaN    535.24      NaN      NaN
# Iceland                    NaN      NaN      NaN     89.96      NaN      NaN
# India                      NaN      NaN      NaN   1386.11      NaN      NaN
# Iran                       NaN      NaN      NaN    708.32      NaN      NaN
# Ireland                    NaN    95.69    93.56    534.51      NaN    47.96
# Israel                  788.30   100.01      NaN    270.08    66.76    50.89
# Italy                   146.21   243.09   421.75   3552.17    52.12    49.97
# Japan                  1529.13   344.10   279.28   5356.99    80.64    50.13
# Lebanon                    NaN      NaN      NaN     89.31      NaN      NaN
# Lithuania                  NaN      NaN      NaN     88.71      NaN      NaN
# Malaysia                   NaN      NaN      NaN    270.05      NaN      NaN
# Mexico                     NaN      NaN      NaN    180.41      NaN      NaN
# Netherlands             290.27   549.60   279.94    270.98    52.42    51.29
# New Zealand                NaN      NaN    93.03    448.32      NaN      NaN
# Norway                  141.17    50.70   139.34    224.75    50.81    50.70
# Poland                     NaN      NaN      NaN    800.95      NaN      NaN
# Portugal                   NaN      NaN   139.44    491.89      NaN      NaN
# Puerto Rico                NaN      NaN      NaN     88.35      NaN      NaN
# Romania                    NaN      NaN      NaN    132.40      NaN      NaN
# Russia                  155.54      NaN    93.04    177.85    56.42      NaN
# Saudi Arabia               NaN      NaN      NaN    356.09      NaN      NaN
# Serbia                     NaN      NaN      NaN     88.84      NaN      NaN
# Singapore               152.16    98.64      NaN       NaN    53.52    49.35
# Slovak Republic            NaN      NaN      NaN     88.98      NaN      NaN
# Slovenia                   NaN      NaN      NaN    178.46      NaN      NaN
# South Africa               NaN    99.15    93.36    271.48      NaN    50.40
# South Korea             279.95   442.23    94.98   2509.12    66.06    50.95
# Spain                      NaN   147.93   186.70   3309.63      NaN    50.17
# Sweden                  253.36   394.45   139.37    362.18    53.64    50.34
# Switzerland             864.08   240.92    47.93    178.50    72.18    49.17
# Taiwan                  108.42      NaN    94.13   1868.02    54.23      NaN
# Thailand                   NaN      NaN    46.55    224.15      NaN      NaN
# Turkey                     NaN      NaN      NaN    889.62      NaN      NaN
# USA                   13617.88  3091.38  2809.10  10185.88   100.00    51.27
# Uganda                     NaN      NaN      NaN     88.56      NaN      NaN
# United Arab Emirates       NaN      NaN      NaN     88.44      NaN      NaN
# United Kingdom         1854.20   783.32  1030.97   3455.86    97.64    49.97
# Uruguay                    NaN      NaN      NaN     88.51      NaN      NaN
#
#                                          amin
# Label                3rd Tier  Other 1st Tier 2nd Tier 3rd Tier  Other
# country
# Argentina                 NaN  45.66      NaN      NaN      NaN  44.10
# Australia               47.47  45.97    44.13    47.97    47.10  44.09
# Austria                 47.78  46.29      NaN      NaN    46.39  44.19
# Belgium                 47.14  46.21    51.72    48.08    46.21  44.31
# Brazil                    NaN  46.08      NaN    49.31      NaN  44.03
# Bulgaria                  NaN  44.48      NaN      NaN      NaN  44.19
# Canada                  47.69  45.74    44.50    47.60    46.17  44.03
# Chile                     NaN  45.33      NaN      NaN      NaN  44.07
# China                   47.76  45.92    52.21    47.56    46.25  44.02
# Colombia                  NaN  44.85      NaN      NaN      NaN  44.06
# Croatia                   NaN  44.92      NaN      NaN      NaN  44.62
# Cyprus                    NaN  44.32      NaN      NaN      NaN  44.10
# Czech Republic          46.32  46.23      NaN      NaN    46.32  44.05
# Denmark                   NaN  45.83    44.15    47.98      NaN  44.59
# Egypt                     NaN  44.52      NaN      NaN      NaN  44.03
# Estonia                   NaN  44.94      NaN      NaN      NaN  44.68
# Finland                   NaN  45.69    44.39    50.04      NaN  44.32
# France                  47.54  45.55    43.36    47.71    45.96  44.04
# Germany                 47.73  46.31    44.32    47.52    46.00  44.13
# Greece                    NaN  46.06      NaN      NaN      NaN  44.13
# Hong Kong               47.83  45.77      NaN    48.15    46.42  44.43
# Hungary                   NaN  45.69      NaN      NaN      NaN  44.14
# Iceland                   NaN  45.05      NaN      NaN      NaN  44.91
# India                     NaN  46.10      NaN      NaN      NaN  44.11
# Iran                      NaN  44.58      NaN      NaN      NaN  44.07
# Ireland                 46.79  45.25      NaN    47.73    46.77  44.05
# Israel                    NaN  45.76    47.45    49.12      NaN  44.36
# Italy                   47.59  46.30    46.34    48.07    46.03  44.12
# Japan                   47.00  45.97    44.52    47.97    46.12  44.06
# Lebanon                   NaN  44.93      NaN      NaN      NaN  44.38
# Lithuania                 NaN  44.46      NaN      NaN      NaN  44.25
# Malaysia                  NaN  46.23      NaN      NaN      NaN  44.49
# Mexico                    NaN  45.99      NaN      NaN      NaN  44.26
# Netherlands             47.11  45.82    43.47    49.30    46.26  44.37
# New Zealand             46.65  45.80      NaN      NaN    46.38  44.09
# Norway                  46.67  46.31    44.26    50.70    46.18  44.26
# Poland                    NaN  45.45      NaN      NaN      NaN  44.06
# Portugal                46.59  45.91      NaN      NaN    46.42  44.03
# Puerto Rico               NaN  44.29      NaN      NaN      NaN  44.06
# Romania                   NaN  44.32      NaN      NaN      NaN  44.04
# Russia                  46.55  45.14    44.93      NaN    46.49  44.04
# Saudi Arabia              NaN  45.45      NaN      NaN      NaN  44.03
# Serbia                    NaN  44.51      NaN      NaN      NaN  44.33
# Singapore                 NaN    NaN    45.20    49.29      NaN    NaN
# Slovak Republic           NaN  44.60      NaN      NaN      NaN  44.38
# Slovenia                  NaN  45.02      NaN      NaN      NaN  44.21
# South Africa            46.78  46.26      NaN    48.75    46.58  44.39
# South Korea             47.79  46.23    46.74    47.60    47.19  44.06
# Spain                   46.99  46.34      NaN    47.97    46.03  44.02
# Sweden                  46.79  46.32    47.61    48.23    46.14  44.44
# Switzerland             47.93  45.05    44.51    47.49    47.93  44.29
# Taiwan                  47.16  45.49    54.19      NaN    46.97  44.04
# Thailand                46.55  45.86      NaN      NaN    46.55  44.21
# Turkey                    NaN  45.57      NaN      NaN      NaN  44.07
# USA                     47.82  46.30    43.88    47.50    45.95  44.09
# Uganda                    NaN  44.40      NaN      NaN      NaN  44.16
# United Arab Emirates      NaN  44.36      NaN      NaN      NaN  44.08
# United Kingdom          47.74  46.30    43.77    47.49    46.05  44.09
# Uruguay                   NaN  44.35      NaN      NaN      NaN  44.16

# %%
#Now we will use another parameter margins and see the chanegs

df.pivot_table(values='score',index='country',columns='Label',aggfunc=[np.sum,np.max,np.min], margins=True).head(10)
# Out:
#                sum                                         amax           \
# Label     1st Tier 2nd Tier 3rd Tier    Other      All 1st Tier 2nd Tier
# country
# Argentina      NaN      NaN      NaN   312.71   312.71      NaN      NaN
# Australia   383.54   393.94    94.57  1785.83  2657.88    51.61    50.40
# Austria        NaN      NaN   141.20   942.15  1083.35      NaN      NaN
# Belgium     103.75   245.42   140.24   450.81   940.22    52.03    49.73
# Brazil         NaN    99.13      NaN  1512.99  1612.12      NaN    49.82
# Bulgaria       NaN      NaN      NaN    88.67    88.67      NaN      NaN
# Canada      697.24   541.40   515.09  1656.14  3409.87    60.87    51.23
# Chile          NaN      NaN      NaN   358.14   358.14      NaN      NaN
# China       214.37   239.34   375.41  6684.64  7513.76    55.30    48.14
# Colombia       NaN      NaN      NaN   177.73   177.73      NaN      NaN
#
#                                      amin
# Label     3rd Tier  Other    All 1st Tier 2nd Tier 3rd Tier  Other    All
# country
# Argentina      NaN  45.66  45.66      NaN      NaN      NaN  44.10  44.10
# Australia    47.47  45.97  51.61    44.13    47.97    47.10  44.09  44.09
# Austria      47.78  46.29  47.78      NaN      NaN    46.39  44.19  44.19
# Belgium      47.14  46.21  52.03    51.72    48.08    46.21  44.31  44.31
# Brazil         NaN  46.08  49.82      NaN    49.31      NaN  44.03  44.03
# Bulgaria       NaN  44.48  44.48      NaN      NaN      NaN  44.19  44.19
# Canada       47.69  45.74  60.87    44.50    47.60    46.17  44.03  44.03
# Chile          NaN  45.33  45.33      NaN      NaN      NaN  44.07  44.07
# China        47.76  45.92  55.30    52.21    47.56    46.25  44.02  44.02
# Colombia       NaN  44.85  44.85      NaN      NaN      NaN  44.06  44.06

# %%
#The pivot table is nothing but it is a dataframe but with multiple order
#Lets save the previous pivot table into a dataframe and have a look at the columns and indexes 

pivot_dataframe = df.pivot_table(values='score',index='country',columns='Label',aggfunc=[np.sum,np.max,np.min])

print(pivot_dataframe.index)

print(pivot_dataframe.columns)
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Iran',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Lebanon', 'Lithuania',
#        'Malaysia', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Puerto Rico', 'Romania', 'Russia', 'Saudi Arabia',
#        'Serbia', 'Singapore', 'Slovak Republic', 'Slovenia', 'South Africa',
#        'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand',
#        'Turkey', 'USA', 'Uganda', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay'],
#       dtype='object', name='country')
# MultiIndex([( 'sum', '1st Tier'),
#             ( 'sum', '2nd Tier'),
#             ( 'sum', '3rd Tier'),
#             ( 'sum',    'Other'),
#             ('amax', '1st Tier'),
#             ('amax', '2nd Tier'),
#             ('amax', '3rd Tier'),
#             ('amax',    'Other'),
#             ('amin', '1st Tier'),
#             ('amin', '2nd Tier'),
#             ('amin', '3rd Tier'),
#             ('amin',    'Other')],
#            names=[None, 'Label'])

# %%
#Let us now see how we can access sum  for 2nd Tier 

pivot_dataframe['sum']['2nd Tier'].head()
# Out:
# country
# Argentina       NaN
# Australia    393.94
# Austria         NaN
# Belgium      245.42
# Brazil        99.13
# Name: 2nd Tier, dtype: float64

# %%
#What if we want to find out the county which has highest maximum score  in 1st Tier

#We will use idxmax() function it is n
pivot_dataframe['sum']['2nd Tier'].idxmax()
# Out:
# 'USA'

# %%
#If you wanted to achieve a different shape of your pivot table, you can do so with the stack and unstack functions. 
#Stacking is pivoting the lowest column index to become the innermost row index, and unstacking is just the inverse of 
#stacking, pivoting the innermost row index to become the lowermost column index. 

pivot_dataframe.stack()
# Out:
#                              sum   amax   amin
# country        Label
# Argentina      Other      312.71  45.66  44.10
# Australia      1st Tier   383.54  51.61  44.13
#                2nd Tier   393.94  50.40  47.97
#                3rd Tier    94.57  47.47  47.10
#                Other     1785.83  45.97  44.09
# ...                          ...    ...    ...
# United Kingdom 1st Tier  1854.20  97.64  43.77
#                2nd Tier   783.32  49.97  47.49
#                3rd Tier  1030.97  47.74  46.05
#                Other     3455.86  46.30  44.09
# Uruguay        Other       88.51  44.35  44.16
#
# [129 rows x 3 columns]

# %% [markdown]
# ## TimeStamp

# %%
#Python majorly has 4 timestamp classes. timestamp, datatimeindex, period, periodindex

#Lets start with timestamp

pd.Timestamp("1/10/2020") #By defualt time will be 00:00:00
# Out:
# Timestamp('2020-01-10 00:00:00')

# %%
#We can pass year, month, day, hour etc seprately

pd.Timestamp(2020,5,12,13,5)
# Out:
# Timestamp('2020-05-12 13:05:00')

# %%
#Timestamp also has some useful attributes, such as isoweekday(), which shows the weekday of the timestamp. 
#Note that 1 represents Monday and 7 represents Sunday.

pd.Timestamp(2021,4,9).isoweekday()
# Out:
# 5

# %%
#We can extract year, month, day, hour etc from timestamp

pd.Timestamp(2021,4,10,9,53).minute
# Out:
# 53

# %% [markdown]
# ### Period

# %%
#suppose we weren't interested in a specific point in time and instead we wanted a span of time. This is where the Period 
#class comes into play. Period represents a single time span, such as a specific day or month

pd.Period("2012-02")
# Out:
# Period('2012-02', 'M')

# %%
#Period objects represent the full time span that you specify. So arithmetic on period is very easy and intuitive. 
#For instance, if we just want to find out 5 months after January 2016, we simply plus 5 to it.

pd.Period("2012-01")+5
# Out:
# Period('2012-06', 'M')

# %%
#Suppose we want to find out 15 days before 2nd March 2016

pd.Period("2016-03-02")-15
# Out:
# Period('2016-02-16', 'D')

# %% [markdown]
# ### DateTimeIndex and PeriodIndex

# %%
#We will create a series which is having a datetimeseries as index

t1 = pd.Series(list('abc'), [pd.Timestamp("2016-01-02"),pd.Timestamp("2016-01-03"),pd.Timestamp("2016-01-04")])
t1
# Out:
# 2016-01-02    a
# 2016-01-03    b
# 2016-01-04    c
# dtype: object

# %%
#Similarly we can do it for period index 
t1 = pd.Series(list('abc'), [pd.Period("2016-01-02"),pd.Period("2016-01-03"),pd.Period("2016-01-04")])
t1
# Out:
# 2016-01-02    a
# 2016-01-03    b
# 2016-01-04    c
# Freq: D, dtype: object

# %% [markdown]
# ### Converting to DateTime

# %%
# let's look into how to convert to Datetime. Suppose we have a list of dates of strings and we want to create a new dataframe.

date = ['2015-2-4','August 2012, 5','7/9/2020','8/9/2020']

df1 = pd.DataFrame(np.random.randint(10,100, (4,2)), index=date, columns=list('ab'))
df1
# Out:
#                  a   b
# 2015-2-4        49  77
# August 2012, 5  22  58
# 7/9/2020        85  48
# 8/9/2020        57  44

# %%
# pandas has these nice built-in to_datetime to try and figure out the format for us.

pd.to_datetime(df1.index)
# Out:
# DatetimeIndex(['2015-02-04', '2012-08-05', '2020-07-09', '2020-08-09'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### TimeDelta

# %%
#It is the difference between the time. Let us say we want to see the time difference between september 9 and November 16.

pd.Timestamp("2021-11-16")-pd.Timestamp("2021-09-08")
# Out:
# Timedelta('69 days 00:00:00')

# %%
#We can also get what will be date and time after 7D 3H from september 9

pd.Timestamp("2021-09-08 8:00AM") + pd.Timedelta("7D 3H")
# Out:
# Timestamp('2021-09-15 11:00:00')

# %% [markdown]
# ### Offset

# %%
#offset is similar to timedelta, but it follows specific calendar duration rules. Offset allows flexibility 
#in terms of types of time intervals. Besides hour, day, week, month, etc., it also has things like business day, 
#and end of month, semi month begin, etc. So very non-traditional time series, but things that we would use in 
#business all the time.

#We will create a timestamp and see what day it is

pd.Timestamp("2021-11-16").weekday()
# Out:
# 1

# %%
#We can add timestamp with a week ahead

pd.Timestamp("2021-11-16") + pd.offsets.Week()
# Out:
# Timestamp('2021-11-23 00:00:00')
